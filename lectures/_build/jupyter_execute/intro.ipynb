# %% [markdown]
# # Quantitative Economics with Julia
#
# This website presents a set of lectures on quantitative economic modeling, designed and written by [Jesse Perla](https://www.jesseperla.com), [Thomas J. Sargent](http://www.tomsargent.com/) and [John Stachurski](http://johnstachurski.net/). The language instruction is Julia.
#
# ```{tableofcontents}
# ```
#
#
#
# ```{toctree}
# :hidden:
# :titlesonly:
# :numbered: True
# :caption: Getting Started with Julia
#
# getting_started_julia/getting_started
# getting_started_julia/julia_environment
# getting_started_julia/julia_by_example
# getting_started_julia/julia_essentials
# getting_started_julia/fundamental_types
# getting_started_julia/introduction_to_types
# ```
#
#
# ```{toctree}
# :hidden:
# :titlesonly:
# :numbered: True
# :caption: Packages and Software Engineering in Julia
#
# more_julia/generic_programming
# more_julia/general_packages
# more_julia/data_statistical_packages
# more_julia/optimization_solver_packages
# more_julia/tools_editors
# more_julia/version_control
# more_julia/testing
# more_julia/need_for_speed
# ```
#
#
# ```{toctree}
# :hidden:
# :titlesonly:
# :numbered: True
# :caption: Tools and Techniques
#
# tools_and_techniques/linear_algebra
# tools_and_techniques/orth_proj
# tools_and_techniques/lln_clt
# tools_and_techniques/linear_models
# tools_and_techniques/finite_markov
# tools_and_techniques/stationary_densities
# tools_and_techniques/kalman
# tools_and_techniques/numerical_linear_algebra
# tools_and_techniques/iterative_methods_sparsity
# ```
#
#
# ```{toctree}
# :hidden:
# :titlesonly:
# :numbered: True
# :caption: Dynamic Programming
#
# dynamic_programming/short_path
# dynamic_programming/mccall_model
# dynamic_programming/mccall_model_with_separation
# dynamic_programming/wald_friedman
# dynamic_programming/odu
# dynamic_programming/career
# dynamic_programming/jv
# dynamic_programming/optgrowth
# dynamic_programming/coleman_policy_iter
# dynamic_programming/egm_policy_iter
# dynamic_programming/lqcontrol
# dynamic_programming/perm_income
# dynamic_programming/perm_income_cons
# dynamic_programming/smoothing
# dynamic_programming/ifp
# dynamic_programming/robustness
# dynamic_programming/discrete_dp
# ```
#
#
# ```{toctree}
# :hidden:
# :titlesonly:
# :numbered: True
# :caption: Modeling in Continuous Time
#
# continuous_time/seir_model
# continuous_time/covid_sde
# ```
#
#
# ```{toctree}
# :hidden:
# :titlesonly:
# :numbered: True
# :caption: Multiple Agent Models
#
# multi_agent_models/schelling
# multi_agent_models/lake_model
# multi_agent_models/rational_expectations
# multi_agent_models/markov_perf
# multi_agent_models/markov_asset
# multi_agent_models/lucas_model
# multi_agent_models/harrison_kreps
# multi_agent_models/uncertainty_traps
# multi_agent_models/aiyagari
# multi_agent_models/arellano
# multi_agent_models/matsuyama
# ```
#
#
# ```{toctree}
# :hidden:
# :titlesonly:
# :numbered: True
# :caption: Time Series Models
#
# time_series_models/arma
# time_series_models/estspec
# time_series_models/additive_functionals
# time_series_models/multiplicative_functionals
# time_series_models/lu_tricks
# time_series_models/classical_filtering
# ```
#
#
# ```{toctree}
# :hidden:
# :titlesonly:
# :numbered: True
# :caption: Dynamic Programming Squared
#
# dynamic_programming_squared/dyn_stack
# dynamic_programming_squared/lqramsey
# dynamic_programming_squared/opt_tax_recur
# dynamic_programming_squared/amss
# ```
#
#
# ```{toctree}
# :hidden:
# :titlesonly:
# :numbered: True
# :caption: Other
#
# about_lectures
# troubleshooting
# zreferences
# status
# ```
